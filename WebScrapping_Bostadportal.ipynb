# %% [markdown]
# <a href="https://colab.research.google.com/github/Omarnot2far/Web_Scraping_Data/blob/main/WebScrapping_Bostadportal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# Web scraping is a powerful technique used to extract and analyze data from websites. In this example, we will use Panda and BeautifulSoup to scrape apartment listings from the Bostadsportal website https://bostadsportal.se/ and organize the data into a tabular format by cleaning the data.

# %% [markdown]
# # Install and import the Libraries

# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4) (2.4)

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests) (1.26.15)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# url from Hemnet website
url = 'https://bostadsportal.se/hyra-l%C3%A4genhet,hyra-rum,hyra-hus,hyra-stuga/stockholm/'

# %%
# get a request to the url 
page = requests.get(url)

# %%
# parse the html page content into the Beautifull soup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# now, find all the content from the html page
lists = soup.find_all('div', class_= 'css-1jf5j4m')

# %%
# Initialize an empty list to store the data
data = []

# Extract the data from each listing
for list in lists:
    title_elem = list.find('div', class_='css-uom1tl')
    title = title_elem.text[7:] if title_elem else ''

    location_elem = list.find('div', class_='css-22506a')
    location = location_elem.text if location_elem else ''

    room_elem = list.find('span', class_="css-1ynu4tx")
    room = room_elem.text if room_elem else ''

    price_elem = list.find('span', class_="css-1wltohh")
    price = price_elem.text if price_elem else ''

    # Add the data to the list
    data.append([title, location, room, price])

# Convert the list of data into a DataFrame
df = pd.DataFrame(data, columns=['Size', 'Location', 'Room', 'Price'])

# Print the DataFrame
print(df)
# Out:
#                                                  Size  \
# 0                 Lägenhet · 79 m²Rinkeby, Almbygatan
# 1   Lägenhet · 56 m²Hägersten-Liljeholmen, Bryggvägen
# 2             Lägenhet · 28 m²Spånga-Tensta, Nekvägen
# 3   Lägenhet · 26 m²Hässelby-Vällingby, Enspännarg...
# 4             Lägenhet · 58 m²Östermalm, Madängsgatan
# 5                 Lägenhet · 60 m²Norrmalm, Hagagatan
# 6    Lägenhet · 41 m²Hässelby-Vällingby, Persikogatan
# 7   Lägenhet · 104 m²Hässelby-Vällingby, Skattegår...
# 8           Lägenhet · 53 m²Kungsholmen, Polhemsgatan
# 9                 Rum · 18 m²Östermalm, Forskarbacken
# 10                Rum · 18 m²Östermalm, Körsbärsvägen
# 11               Lägenhet · 29 m²Södermalm, Maltgatan
# 12           Lägenhet · 42 m²Norrmalm, Holländargatan
# 13  Lägenhet · 194 m²Hässelby-Vällingby, Sjötorpsb...
# 14   Lägenhet · 65 m²Hässelby-Vällingby, Ormängsgatan
# 15   Lägenhet · 69 m²Hässelby-Vällingby, Spiralbacken
# 16             Lägenhet · 45 m²Norrmalm, Vanadisvägen
# 17   Lägenhet · 50 m²Hässelby-Vällingby, Vemdalsgatan
# 18            · Lägenhet · 39 m²Storskogen, Tulegatan
# 19             Lägenhet · 48 m²Storskogen, Fredsgatan
# 20     Lägenhet · 12 m²Storskogen, Skogsbacken 16 lgh
# 21              Lägenhet · 66 m²Storskogen, Tulegatan
# 22             Lägenhet · 55 m²Storskogen, Vattugatan
# 23            Lägenhet · 100 m²Storskogen, Mariagatan
# 24
#
#                                 Location  \
# 0                    Rinkeby, Almbygatan
# 1      Hägersten-Liljeholmen, Bryggvägen
# 2                Spånga-Tensta, Nekvägen
# 3     Hässelby-Vällingby, Enspännargatan
# 4                Östermalm, Madängsgatan
# 5                    Norrmalm, Hagagatan
# 6       Hässelby-Vällingby, Persikogatan
# 7   Hässelby-Vällingby, Skattegårdsvägen
# 8              Kungsholmen, Polhemsgatan
# 9               Östermalm, Forskarbacken
# 10              Östermalm, Körsbärsvägen
# 11                  Södermalm, Maltgatan
# 12              Norrmalm, Holländargatan
# 13   Hässelby-Vällingby, Sjötorpsbrinken
# 14      Hässelby-Vällingby, Ormängsgatan
# 15      Hässelby-Vällingby, Spiralbacken
# 16                Norrmalm, Vanadisvägen
# 17      Hässelby-Vällingby, Vemdalsgatan
# 18                 Storskogen, Tulegatan
# 19                Storskogen, Fredsgatan
# 20        Storskogen, Skogsbacken 16 lgh
# 21                 Storskogen, Tulegatan
# 22                Storskogen, Vattugatan
# 23                Storskogen, Mariagatan
# 24
#
#                                                  Room      Price
# 0                            5 rums lägenhet i Spånga  13 960 kr
# 1                         2 rums lägenhet i Stockholm  13 306 kr
# 2                         1 rums lägenhet i Stockholm   7 429 kr
# 3                          1 rums lägenhet i Hässelby   4 299 kr
# 4                         2 rums lägenhet i Stockholm  12 239 kr
# 5   Hagagatan välkomnar er till en exklusiv, total...  24 500 kr
# 6                            1 rums lägenhet i Strand   5 006 kr
# 7                         4 rums lägenhet i Stockholm  16 940 kr
# 8                             Lägenhet i Kungsholmen   17 000 kr
# 9                         1 rums lägenhet i Stockholm   4 086 kr
# 10                        1 rums lägenhet i Stockholm   4 096 kr
# 11                        1 rums lägenhet i Stockholm   6 485 kr
# 12                        1 rums lägenhet i Stockholm   8 801 kr
# 13  Läcker modern villa med  utomhuspool och utsik...  29 900 kr
# 14                             3 rums lägenhet i Gård   5 657 kr
# 15                           3 rums lägenhet i Strand   6 232 kr
# 16                          2 rums bostad i Stockholm  18 100 kr
# 17                          2 rums bostad i Vällingby   9 607 kr
# 18            Ytterst fin lgh i unikt läge våning 13   14 000 kr
# 19                                Skötsam inneboende    5 000 kr
# 20                              Möblerat eller delvis   4 500 kr
# 21                       2 rums lägenhet i Sundbyberg   8 800 kr
# 22                         2 rums bostad i Sundbyberg   3 900 kr
# 23                                         Mariagatan   9 408 kr
# 24

# %%
df.head()
# Out:
#                                                 Size  \
# 0                Lägenhet · 79 m²Rinkeby, Almbygatan
# 1  Lägenhet · 56 m²Hägersten-Liljeholmen, Bryggvägen
# 2            Lägenhet · 28 m²Spånga-Tensta, Nekvägen
# 3  Lägenhet · 26 m²Hässelby-Vällingby, Enspännarg...
# 4            Lägenhet · 58 m²Östermalm, Madängsgatan
#
#                              Location                         Room      Price
# 0                 Rinkeby, Almbygatan     5 rums lägenhet i Spånga  13 960 kr
# 1   Hägersten-Liljeholmen, Bryggvägen  2 rums lägenhet i Stockholm  13 306 kr
# 2             Spånga-Tensta, Nekvägen  1 rums lägenhet i Stockholm   7 429 kr
# 3  Hässelby-Vällingby, Enspännargatan   1 rums lägenhet i Hässelby   4 299 kr
# 4             Östermalm, Madängsgatan  2 rums lägenhet i Stockholm  12 239 kr

# %% [markdown]
# # Data Cleaning

# %%
# Split the 'Size' column by '·' and extract the second part
# str.strip() method to remove any leading or trailing whitespace from the size value.
df['type'] = df['Size'].str.split('·').str[0].str.strip()

# Split the 'Size' column by '·' and extract the second part
df['size'] = df['Size'].str.split('·').str[1].str.strip()

# %%
df.head()
# Out:
#                                                 Size  \
# 0                Lägenhet · 79 m²Rinkeby, Almbygatan
# 1  Lägenhet · 56 m²Hägersten-Liljeholmen, Bryggvägen
# 2            Lägenhet · 28 m²Spånga-Tensta, Nekvägen
# 3  Lägenhet · 26 m²Hässelby-Vällingby, Enspännarg...
# 4            Lägenhet · 58 m²Östermalm, Madängsgatan
#
#                              Location                         Room      Price  \
# 0                 Rinkeby, Almbygatan     5 rums lägenhet i Spånga  13 960 kr
# 1   Hägersten-Liljeholmen, Bryggvägen  2 rums lägenhet i Stockholm  13 306 kr
# 2             Spånga-Tensta, Nekvägen  1 rums lägenhet i Stockholm   7 429 kr
# 3  Hässelby-Vällingby, Enspännargatan   1 rums lägenhet i Hässelby   4 299 kr
# 4             Östermalm, Madängsgatan  2 rums lägenhet i Stockholm  12 239 kr
#
#        type                                     size
# 0  Lägenhet                 79 m²Rinkeby, Almbygatan
# 1  Lägenhet   56 m²Hägersten-Liljeholmen, Bryggvägen
# 2  Lägenhet             28 m²Spånga-Tensta, Nekvägen
# 3  Lägenhet  26 m²Hässelby-Vällingby, Enspännargatan
# 4  Lägenhet             58 m²Östermalm, Madängsgatan

# %%
df.drop(columns='Size', inplace=True)

# %%
df.head(24)
# Out:
#                                 Location  \
# 0                    Rinkeby, Almbygatan
# 1      Hägersten-Liljeholmen, Bryggvägen
# 2                Spånga-Tensta, Nekvägen
# 3     Hässelby-Vällingby, Enspännargatan
# 4                Östermalm, Madängsgatan
# 5                    Norrmalm, Hagagatan
# 6       Hässelby-Vällingby, Persikogatan
# 7   Hässelby-Vällingby, Skattegårdsvägen
# 8              Kungsholmen, Polhemsgatan
# 9               Östermalm, Forskarbacken
# 10              Östermalm, Körsbärsvägen
# 11                  Södermalm, Maltgatan
# 12              Norrmalm, Holländargatan
# 13   Hässelby-Vällingby, Sjötorpsbrinken
# 14      Hässelby-Vällingby, Ormängsgatan
# 15      Hässelby-Vällingby, Spiralbacken
# 16                Norrmalm, Vanadisvägen
# 17      Hässelby-Vällingby, Vemdalsgatan
# 18                 Storskogen, Tulegatan
# 19                Storskogen, Fredsgatan
# 20        Storskogen, Skogsbacken 16 lgh
# 21                 Storskogen, Tulegatan
# 22                Storskogen, Vattugatan
# 23                Storskogen, Mariagatan
#
#                                                  Room      Price      type  \
# 0                            5 rums lägenhet i Spånga  13 960 kr  Lägenhet
# 1                         2 rums lägenhet i Stockholm  13 306 kr  Lägenhet
# 2                         1 rums lägenhet i Stockholm   7 429 kr  Lägenhet
# 3                          1 rums lägenhet i Hässelby   4 299 kr  Lägenhet
# 4                         2 rums lägenhet i Stockholm  12 239 kr  Lägenhet
# 5   Hagagatan välkomnar er till en exklusiv, total...  24 500 kr  Lägenhet
# 6                            1 rums lägenhet i Strand   5 006 kr  Lägenhet
# 7                         4 rums lägenhet i Stockholm  16 940 kr  Lägenhet
# 8                             Lägenhet i Kungsholmen   17 000 kr  Lägenhet
# 9                         1 rums lägenhet i Stockholm   4 086 kr       Rum
# 10                        1 rums lägenhet i Stockholm   4 096 kr       Rum
# 11                        1 rums lägenhet i Stockholm   6 485 kr  Lägenhet
# 12                        1 rums lägenhet i Stockholm   8 801 kr  Lägenhet
# 13  Läcker modern villa med  utomhuspool och utsik...  29 900 kr  Lägenhet
# 14                             3 rums lägenhet i Gård   5 657 kr  Lägenhet
# 15                           3 rums lägenhet i Strand   6 232 kr  Lägenhet
# 16                          2 rums bostad i Stockholm  18 100 kr  Lägenhet
# 17                          2 rums bostad i Vällingby   9 607 kr  Lägenhet
# 18            Ytterst fin lgh i unikt läge våning 13   14 000 kr
# 19                                Skötsam inneboende    5 000 kr  Lägenhet
# 20                              Möblerat eller delvis   4 500 kr  Lägenhet
# 21                       2 rums lägenhet i Sundbyberg   8 800 kr  Lägenhet
# 22                         2 rums bostad i Sundbyberg   3 900 kr  Lägenhet
# 23                                         Mariagatan   9 408 kr  Lägenhet
#
#       Sq_m
# 0    79 m²
# 1    56 m²
# 2    28 m²
# 3    26 m²
# 4    58 m²
# 5    60 m²
# 6    41 m²
# 7   104 m²
# 8    53 m²
# 9    18 m²
# 10   18 m²
# 11   29 m²
# 12   42 m²
# 13  194 m²
# 14   65 m²
# 15   69 m²
# 16   45 m²
# 17   50 m²
# 18     NaN
# 19   48 m²
# 20   12 m²
# 21   66 m²
# 22   55 m²
# 23  100 m²

# %%
# Extract the size value as a separate column
# \d+ capture the digits as a group
df['Sq_m'] = df['size'].str.extract(r'(\d+ m²)')

# remove size column
df.drop(columns='size', inplace=True)

# %%
# Extract the number of rooms as a separate column
df['Rooms'] = df['Room'].str.extract(r'(\d+) rums')

# remove the Room column
df.drop(columns='Room', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Location  25 non-null     object
#  1   Price     25 non-null     object
#  2   type      25 non-null     object
#  3   Sq_m      23 non-null     object
#  4   Rooms     17 non-null     object
# dtypes: object(5)
# memory usage: 1.1+ KB
